# %%
import pandas as pd

dfTrain = pd.read_csv (r'Data/test_timeseries.csv')
dfTest = pd.read_csv (r'Data/train_timeseries.csv')
dfValid = pd.read_csv (r'Data/validation_timeseries.csv')

# %%
dfTrain.head()
dfTest.head()
dfValid.head()
# Out:
#    fips        date  PRECTOT      PS   QV2M    T2M  T2MDEW  T2MWET  T2M_MAX  \
# 0  1001  2017-01-01    32.50  100.02  10.47  14.69   14.47   14.47    17.68
# 1  1001  2017-01-02    63.52  100.04  12.75  17.96   17.75   17.75    20.30
# 2  1001  2017-01-03    18.82   99.69   9.74  14.24   13.44   13.44    18.48
# 3  1001  2017-01-04     0.01  100.02   5.21   8.10    3.86    3.88    11.74
# 4  1001  2017-01-05     0.01   99.89   4.54   5.91    2.20    2.22    13.07
#
#    T2M_MIN  ...     TS  WS10M  WS10M_MAX  WS10M_MIN  WS10M_RANGE  WS50M  \
# 0    10.53  ...  14.63   2.14       2.71       1.52         1.19   4.40
# 1    16.14  ...  17.85   2.75       4.31       1.60         2.71   5.50
# 2     9.29  ...  14.06   2.25       3.73       1.64         2.09   4.80
# 3     2.12  ...   8.08   2.63       3.95       1.34         2.60   4.98
# 4    -0.18  ...   5.85   1.76       2.76       0.47         2.28   3.43
#
#    WS50M_MAX  WS50M_MIN  WS50M_RANGE  score
# ...

# %%
dfTest = dfTest.dropna()

# %%
import matplotlib.pyplot as plt
plt.scatter(dfTest['score'], dfTest['PRECTOT'])
plt.show()

# %%
rounded = dfTest['score'].round(decimals=0)

# %%
rounded.head()
# Out:
# 3     1.0
# 10    2.0
# 17    2.0
# 24    2.0
# 31    1.0
# Name: score, dtype: float64

# %%
plt.scatter(rounded, dfTest['PRECTOT'])

# %%
plt.scatter(dfTest['PRECTOT'], rounded, dfTest['WS10M_MAX'])
# Out:
# Error in callback <function flush_figures at 0x7f8082fe7430> (for post_execute):
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/ipykernel/pylab/backend_inline.py in flush_figures()
#     119         # ignore the tracking, just draw and close all figures
#     120         try:
# --> 121             return show(True)
#     122         except Exception as e:
#     123             # safely show traceback if in IPython, else raise
#
# ~/opt/anaconda3/lib/python3.8/site-packages/ipykernel/pylab/backend_inline.py in show(close, block)
#      39     try:
#      40         for figure_manager in Gcf.get_all_fig_managers():
# ---> 41             display(
#      42                 figure_manager.canvas.figure,
#      43                 metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#
# ...

# %%
fig = plt.figure(figsize = (10, 7))
ax = plt.axes(projection ="3d")
ax.scatter3D(dfTest['PRECTOT'], rounded, dfTest['WS10M_MAX'], color = "green")
plt.title("simple 3D scatter plot")
plt.show()
