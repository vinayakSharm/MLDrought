# %%
import pandas as pd

dfTrain = pd.read_csv (r'Data/test_timeseries.csv')
dfTest = pd.read_csv (r'Data/train_timeseries.csv')
dfValid = pd.read_csv (r'Data/validation_timeseries.csv')

# %%
dfTrain.head()
dfTest.head()
dfValid.head()
# Out:
#    fips        date  PRECTOT      PS   QV2M    T2M  T2MDEW  T2MWET  T2M_MAX  \
# 0  1001  2017-01-01    32.50  100.02  10.47  14.69   14.47   14.47    17.68
# 1  1001  2017-01-02    63.52  100.04  12.75  17.96   17.75   17.75    20.30
# 2  1001  2017-01-03    18.82   99.69   9.74  14.24   13.44   13.44    18.48
# 3  1001  2017-01-04     0.01  100.02   5.21   8.10    3.86    3.88    11.74
# 4  1001  2017-01-05     0.01   99.89   4.54   5.91    2.20    2.22    13.07
#
#    T2M_MIN  ...     TS  WS10M  WS10M_MAX  WS10M_MIN  WS10M_RANGE  WS50M  \
# 0    10.53  ...  14.63   2.14       2.71       1.52         1.19   4.40
# 1    16.14  ...  17.85   2.75       4.31       1.60         2.71   5.50
# 2     9.29  ...  14.06   2.25       3.73       1.64         2.09   4.80
# 3     2.12  ...   8.08   2.63       3.95       1.34         2.60   4.98
# 4    -0.18  ...   5.85   1.76       2.76       0.47         2.28   3.43
#
#    WS50M_MAX  WS50M_MIN  WS50M_RANGE  score
# 0       5.96       2.25         3.71    NaN
# 1       8.16       4.05         4.11    NaN
# 2       7.27       2.54         4.72    2.0
# 3       6.16       3.36         2.80    NaN
# 4       4.70       0.66         4.04    NaN
#
# [5 rows x 21 columns]

# %%
dfTest.dropna()
# Out:
#            fips        date  PRECTOT      PS  QV2M    T2M  T2MDEW  T2MWET  \
# 3          1001  2000-01-04    15.95  100.29  6.42  11.40    6.09    6.10
# 10         1001  2000-01-11     1.33  100.40  6.63  11.48    7.84    7.84
# 17         1001  2000-01-18     1.11  100.39  9.53  14.28   13.26   13.26
# 24         1001  2000-01-25     0.00  100.11  2.05  -0.78   -7.93   -7.72
# 31         1001  2000-02-01     0.00  101.00  3.36   2.06   -1.73   -1.70
# ...         ...         ...      ...     ...   ...    ...     ...     ...
# 19300647  56043  2016-11-29     0.04   82.47  2.19  -4.27   -9.36   -9.26
# 19300654  56043  2016-12-06     0.13   82.59  0.91 -11.96  -18.65  -17.90
# 19300661  56043  2016-12-13     0.02   82.86  1.40  -9.56  -14.18  -13.95
# 19300668  56043  2016-12-20     0.32   83.12  2.73  -2.55   -6.90   -6.84
# 19300675  56043  2016-12-27     0.16   82.88  1.63  -7.97  -13.49  -12.81
#
#           T2M_MAX  T2M_MIN  ...     TS  WS10M  WS10M_MAX  WS10M_MIN  \
# 3           18.09     2.16  ...  11.31   3.84       5.67       2.08
# 10          18.88     5.72  ...  10.43   1.76       2.48       1.05
# 17          18.04     8.98  ...  14.19   2.63       3.60       1.67
# 24           5.65    -5.46  ...  -0.61   3.35       4.59       2.28
# 31          11.02    -4.21  ...   1.88   2.03       2.74       0.88
# ...           ...      ...  ...    ...    ...        ...        ...
# 19300647    -1.51    -7.22  ...  -4.38   6.93      10.27       3.08
# 19300654    -6.85   -15.24  ... -11.98   2.27       3.97       0.95
# 19300661    -2.69   -13.01  ... -10.95   3.64       6.59       1.28
# 19300668     2.66    -7.77  ...  -3.94   6.16       8.43       3.44
# 19300675    -1.39   -13.60  ...  -9.41   5.90       7.63       3.61
#
#           WS10M_RANGE  WS50M  WS50M_MAX  WS50M_MIN  WS50M_RANGE  score
# 3                3.59   6.73       9.31       3.74         5.58    1.0
# 10               1.43   3.55       6.38       1.71         4.67    2.0
# 17               1.92   5.19       6.40       3.84         2.55    2.0
# 24               2.32   5.75       8.03       3.96         4.07    2.0
# 31               1.86   4.18       6.38       1.27         5.11    1.0
# ...               ...    ...        ...        ...          ...    ...
# 19300647         7.18   9.42      12.59       5.62         6.97    0.0
# 19300654         3.02   3.07       5.16       0.83         4.33    0.0
# 19300661         5.31   5.33       8.35       2.13         6.22    0.0
# 19300668         4.99   8.99      10.14       6.67         3.47    0.0
# 19300675         4.02   8.58      10.39       5.92         4.47    0.0
#
# [2756796 rows x 21 columns]

# %%
import matplotlib.pyplot as plt
plt.scatter(dfTest['score'], dfTest['PRECTOT'])
plt.show()
